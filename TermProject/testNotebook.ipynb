# %% [markdown]
# import the two analysis classes

# %%
from analysisState import AnalysisState
from analysisCountry import AnalysisCountry

# %% [markdown]
# Create analysis object and pass the jobtype and zip code

# %%
state = AnalysisState("SAS", "07059")

# retrieve jobs from api and store them in mongodb
state.retrieveAndStoreJobs()
# Out:
# Retrieving jobs from URL:
# http://service.dice.com/api/rest/jobsearch/v1/simple.json?text=sas&city=07059
# Dropping collection sas07059
# Count the jobs for a jobTitle and location
# Retrieved 108 jobs and stored them in MongoDB

# %%
# get top20 companies hiring jobtype around the zipcode
state.getTop20Companies(barplot=False)
state.getTop20Companies()
# Out:
# Printing top companies
# Company  JobCount
#                            UBS         7
#       U.S. Tech Solutions Inc.         4
#                    Kforce Inc.         4
#                   TNT Staffing         3
#  Cardinal Technology Solutions         3
#          Sunrise Systems, Inc.         2
#                          EDPSI         2
#                     Page Group         2
#    Brightech International LLC         2
#                     Stratacent         2
#                 Aegistech Inc.         2
#                The Judge Group         2
# Atrilogy Solutions Group, Inc.         2
#                  Intellisearch         1
#                       Kelly IT         1
#           Intone Networks Inc.         1
#      The Coddington Group, LLC         1
#                      X-pertize         1
#         Rang Technologies Inc.         1
#        Capricorn Systems, Inc.         1
# Printing top companies
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Company</th>
#       <th>JobCount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>UBS</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>U.S. Tech Solutions Inc.</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Kforce Inc.</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>TNT Staffing</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Cardinal Technology Solutions</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Sunrise Systems, Inc.</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>EDPSI</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Page Group</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Brightech International LLC</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Stratacent</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Aegistech Inc.</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>The Judge Group</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Atrilogy Solutions Group, Inc.</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Intellisearch</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Kelly IT</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Intone Networks Inc.</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>The Coddington Group, LLC</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>X-pertize</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Rang Technologies Inc.</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Capricorn Systems, Inc.</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Create country-level analysis object and pass the jobtype and zip code
country = AnalysisCountry("SAS", "US")

# %%
# retrieve jobs from the api and store them in mongodb
country.retrieveAndStoreJobs()

# get top company by state
country.getTopCompanyByState()
# Out:
# Retrieving jobs from URL:
# http://service.dice.com/api/rest/jobsearch/v1/simple.json?text=sas&country=US
# Dropping collection sasUS
# Retrieved 879 jobs and stored them in MongoDB
# Group jobs by state and company, display the top company per state
# Display the top company with every state
# company state
#                                    Regions Bank    AL
#         General Dynamics Information Technology    AR
#                                BCBSAZ Advantage    AZ
#                         SUPERMICRO COMPUTER INC    CA
#                                  Charles Schwab    CO
#                                     Srinav Inc.    CT
#                           Datanet Systems Corp.    DC
#                                     Kforce Inc.    DE
#                                        Deloitte    FL
#                       Principle Solutions Group    GA
#                                   SAS Quest LLC    IA
#                            United Airlines Inc.    IL
#                                         Experis    IN
#                                          NetApp    KS
#                                  Latitude36 Inc    KY
#                  Louisiana Economic Development    LA
#                              UnitedHealth Group    MA
#                                       Mindlance    MD
#                              IDEXX Laboratories    ME
#                              Quicken Loans Inc.    MI
#                              UnitedHealth Group    MN
#                                     CenturyLink    MO
#                        Career Resource Services    MS
#                                          ApTask    NC
#                      Continental Resources Inc.    NH
#                                             UBS    NJ
#                                          RESPEC    NM
#                   Irvine Technology Corporation    NV
#                                      Stratacent    NY
#                       Principle Solutions Group    OH
#                                        comScore    OR
# Pennsylvania Higher Education Assistance Agency    PA
#                                 The Judge Group    RI
#                                       e-Primary    SC
#                            Securus Technologies    SD
#                                 KBM Enterprises    TN
#                                   SAS Quest LLC    TX
#                    Western Governors University    UT
#                                        Deloitte    VA
#                             Concur Technologies    WA
#                             Beacon Technologies    WI
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>company</th>
#       <th>state</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Regions Bank</td>
#       <td>AL</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>General Dynamics Information Technology</td>
#       <td>AR</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>BCBSAZ Advantage</td>
#       <td>AZ</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>SUPERMICRO COMPUTER INC</td>
#       <td>CA</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Charles Schwab</td>
#       <td>CO</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Srinav Inc.</td>
#       <td>CT</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Datanet Systems Corp.</td>
#       <td>DC</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Kforce Inc.</td>
#       <td>DE</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Deloitte</td>
#       <td>FL</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Principle Solutions Group</td>
#       <td>GA</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>SAS Quest LLC</td>
#       <td>IA</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>United Airlines Inc.</td>
#       <td>IL</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Experis</td>
#       <td>IN</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>NetApp</td>
#       <td>KS</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Latitude36 Inc</td>
#       <td>KY</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Louisiana Economic Development</td>
#       <td>LA</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>UnitedHealth Group</td>
#       <td>MA</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Mindlance</td>
#       <td>MD</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>IDEXX Laboratories</td>
#       <td>ME</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Quicken Loans Inc.</td>
#       <td>MI</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>UnitedHealth Group</td>
#       <td>MN</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>CenturyLink</td>
#       <td>MO</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Career Resource Services</td>
#       <td>MS</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>ApTask</td>
#       <td>NC</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>Continental Resources Inc.</td>
#       <td>NH</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>UBS</td>
#       <td>NJ</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>RESPEC</td>
#       <td>NM</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>Irvine Technology Corporation</td>
#       <td>NV</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>Stratacent</td>
#       <td>NY</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>Principle Solutions Group</td>
#       <td>OH</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>comScore</td>
#       <td>OR</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>Pennsylvania Higher Education Assistance Agency</td>
#       <td>PA</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>The Judge Group</td>
#       <td>RI</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>e-Primary</td>
#       <td>SC</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>Securus Technologies</td>
#       <td>SD</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>KBM Enterprises</td>
#       <td>TN</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>SAS Quest LLC</td>
#       <td>TX</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>Western Governors University</td>
#       <td>UT</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>Deloitte</td>
#       <td>VA</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>Concur Technologies</td>
#       <td>WA</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>Beacon Technologies</td>
#       <td>WI</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# get number of jobs per state
country.getJobsByState(barplot=False)
country.getJobsByState()
# Out:
# Group jobs by state and list top 20 states
# Printing top companies
# jobcount state
#      117    CA
#       74    TX
#       73    NY
#       59    NJ
#       58    VA
#       52    IL
#       44    GA
#       39    FL
#       36    MD
#       34    DC
#       34    MA
#       29    NC
#       25    PA
#       25    CT
#       17    OH
#       16    DE
#       15    MN
#       11    CO
#       11    AZ
#       10    WA
# Group jobs by state and list top 20 states
# Printing top companies
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>jobcount</th>
#       <th>state</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>117</td>
#       <td>CA</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>74</td>
#       <td>TX</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>73</td>
#       <td>NY</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>59</td>
#       <td>NJ</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>58</td>
#       <td>VA</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>52</td>
#       <td>IL</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>44</td>
#       <td>GA</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>39</td>
#       <td>FL</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>36</td>
#       <td>MD</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>34</td>
#       <td>DC</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>34</td>
#       <td>MA</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>29</td>
#       <td>NC</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>25</td>
#       <td>PA</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>25</td>
#       <td>CT</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>17</td>
#       <td>OH</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>16</td>
#       <td>DE</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>15</td>
#       <td>MN</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>11</td>
#       <td>CO</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>11</td>
#       <td>AZ</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>10</td>
#       <td>WA</td>
#     </tr>
#   </tbody>
# </table>
# </div>
